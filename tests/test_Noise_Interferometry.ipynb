# %% [markdown]
# # Noise Interferometry Demo
#
# First, let's import all of the dependancies

# %%
import multiprocessing as mp
import numpy as np
import sys
import os
import numpy as np
import scipy
import datetime
from matplotlib import pyplot as plt
import pickle
import seaborn as sns

#Adding OOIPY Home Directory to Path
cwd = os.getcwd()
ooipy_dir = os.path.dirname(os.path.dirname(cwd))
sys.path.append(ooipy_dir)
from ooipy.hydrophone import Noise_Interferometry as NI

# Some more magic so that the notebook will reload external python modules;
# see http://stackoverflow.com/questions/1907993/autoreload-of-modules-in-ipython
# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# ## Using the Non-Looping Functionality
# Since Noise Interferometry is usually calculated over long periods, the ability to loop through different average periods is available. First let's walk through how to do a single period calculation. This returns the NCF object.

# %% [markdown]
# This sets up all of the input parameters and initializes an instance of the NCF object

# %%
avg_time = 1 #minutes
start_time = datetime.datetime(2017,3,10,0,0,0) # time of first sample
node1 = '/LJ01C'
node2 = '/PC01A'
filter_cutoffs = np.array([10, 950])
W = 30

NCF_object = NI.NCF(avg_time, start_time, node1, node2, filter_cutoffs, W, verbose=True, whiten=False)

# %%
NCF_object = NI.get_audio(NCF_object)
# Out:
#    Getting Audio from Node 1...
#    Getting Audio from Node 2...

# %%
NCF_object.whiten=False
NCF_object = NI.preprocess_audio(NCF_object)
NCF_object = NI.calc_xcorr(NCF_object)
# Out:
#    Filtering and Whitening Data for Node 1...
#    Filtering and Whitening Data for Node 2...
#    Correlating Data...

# %%
plt.plot(NCF_object.NCF)

# %% [markdown]
# ## Using Loop Functionality
# This saves the NCF for each average periods in the directory ./ckpts/
# This example is just doing 2 loops

# %%
num_periods = 2
NI.calculate_NCF_loop(num_periods, node1, node2, avg_time, start_time, W,  filter_cutoffs, verbose=True)
# Out:
# Calculting NCF for Period 2017-03-10 00:00:00 - 2017-03-10 00:01:00:
#    Getting Audio from Node 1...
#    Getting Audio from Node 2...
#    Filtering and Whitening Data for Node 1...
#    Filtering and Whitening Data for Node 2...
#    Correlating Data...
#    Time to Calculate NCF for 1 Average Period: 9.182828426361084
#
#
# Calculting NCF for Period 2017-03-10 00:01:00 - 2017-03-10 00:02:00:
#    Getting Audio from Node 1...
#    Getting Audio from Node 2...
#    Filtering and Whitening Data for Node 1...
#    Filtering and Whitening Data for Node 2...
#    Correlating Data...
#    Time to Calculate NCF for 1 Average Period: 8.90283751487732

# %% [markdown]
# ## Creating Single NCF from saved Chekpoints

# %%
num_periods = 2

header_name = './ckpts/0HEADER.pkl'
with open(header_name, 'rb') as f:
    header = pickle.load(f)

print(f'Start Time: {header.start_time}')
print(f'Average Period: {header.avg_time} (minutes)')
print(f'Number of Periods: {header.num_periods}')
print(f'Frequency Range: {header.filter_cutoffs} (Hz)')
for k in range(num_periods):
    ckpt_name = './ckpts/ckpt_'+str(k)+'.pkl'
    with open(ckpt_name, 'rb') as f:
        xcorr_1hr = pickle.load(f)

    if k == 0:
        xcorr = xcorr_1hr
    else:
        xcorr = xcorr + xcorr_1hr

sns.set()
#Plot Xcorr
dt = 1/64000
t = np.arange(-xcorr.shape[0]*dt/2,xcorr.shape[0]*dt/2,dt)

plt.plot(t,xcorr)
# Out:
# Start Time: 2017-03-10 00:00:00
# Average Period: 1 (minutes)
# Number of Periods: 2
# Frequency Range: [20 30] (Hz)

# %% [markdown]
# ## Testing Low Frequency Hydrophone NI

# %%
avg_time = 60 #minutes
start_time = datetime.datetime(2017,3,10,0,0,0) # time of first sample
node1 = 'Central_Caldera'
node2 = 'Eastern_Caldera'
filter_cutoffs = np.array([20, 30])
W = 30
htype = 'low_frequency'

NCF_object = NI.NCF(avg_time, start_time, node1, node2, filter_cutoffs, W, verbose=True, whiten=False, htype=htype)

# %%
NCF_object = NI.calculate_NCF(NCF_object)
# Out:
#    Getting Audio from Node 1...
#    Getting Audio from Node 2...
#    Filtering and Whitening Data for Node 1...
#    Filtering and Whitening Data for Node 2...
#    Correlating Data...
#    Time to Calculate NCF for 1 Average Period: 3.0065600872039795

# %%
NCF_object = NI.get_audio(NCF_object)
# Out:
#    Getting Audio from Node 1...
#    Getting Audio from Node 2...

# %%
NCF_object = NI.preprocess_audio(NCF_object)
# Out:
#    Filtering and Whitening Data for Node 1...
#    Filtering and Whitening Data for Node 2...

# %%
NCF_object = NI.calc_xcorr(NCF_object)
# Out:
#    Correlating Data...

# %%
NCF_object

# %%
NCF_object.NCF
# Out:
# array([  1.59568385e-05,   2.43769309e-04,   9.44778741e-04, ...,
#         -3.59866315e-03,  -9.77108854e-04,   1.30036391e-05])

# %%
plt.plot(NCF_object.NCF)

# %% [markdown]
# # Debugging sabra_processing

# %%
avg_time = 3 #minutes
start_time = datetime.datetime(2017,3,10,0,0,0) # time of first sample
node1 = 'Central_Caldera'
node2 = 'Axial_Base'
filter_cutoffs = np.array([10, 90])
W = 90

NCF_object = NI.NCF(avg_time, start_time, node1, node2, filter_cutoffs, W, verbose=True, whiten=False, htype='low_frequency')

# %%
NCF_object = NI.get_audio(NCF_object)
# Out:
#    Getting Audio from Node 1...
#    Getting Audio from Node 2...

# %%
NCF_object = NI.sabra_processing(NCF_object, plot=True)
# Out:
#    Filtering Data from node 1
#    Filtering Data from node 2

# %%
win = scipy.signal.windows.hann(100)
plt.plot(win)

# %%
NCF_object = NI.calc_xcorr(NCF_object)

plt.plot(NCF_object.NCF)
# Out:
#    Correlating Data...

# %%
avg_time = 1 #minutes
start_time = datetime.datetime(2017,3,10,0,0,0) # time of first sample
node1 = '/LJ01C'
node2 = '/PC01A'
filter_cutoffs = np.array([10, 950])
W = 30

NCF_object = NI.NCF(avg_time, start_time, node1, node2, filter_cutoffs, W, verbose=True, whiten=False)

NCF_object = NI.calculate_NCF(NCF_object)

plt.plot(NCF_object.NCF)
# Out:
#    Getting Audio from Node 1...
#    Getting Audio from Node 2...
#     Filtering Data from node 1
#     Filtering Data from node 2
#    Correlating Data...
#    Time to Calculate NCF for 1 Average        Period: 37.85890793800354

# %% [markdown]
# # Debugging Brown Processing

# %%
NCF_object_processed = NI.brown_processing(NCF_object, plot=True)
# Out:
#    Filtering Data from Node 1...
#    Filtering Data from Node 2...
#    Correlating Data...
#    Whitening short-time data...

# %%
plt.plot(NCF_object.NCF)

# %%
x1 = np.random.rand(1000,1).T
x2 = np.random.rand(1000,1).T

NCF = np.vstack((x1,x2,x1,x2))

print(NCF.shape)

win = np.arange(0,1000)[:,np.newaxis]
print(win.shape)

result = (NCF.T * win).T

plt.plot(result[0,:])
# Out:
# (4, 1000)
# (1000, 1)

# %%
# figureing out how to normalize

x = np.random.rand(100,1000)

max_val = np.max(x, axis=1)

print(x.shape)
print(max_val.shape)

norm = (x.T * max_val).T

print(norm.shape)
print(np.sum(x,axis=0).shape)
# Out:
# (100, 1000)
# (100,)
# (100, 1000)
# (1000,)

# %% [markdown]
# # Trying Sabra Processing with Low Frequency

# %%
avg_time = 60 #minutes
start_time = datetime.datetime(2017,3,10,0,0,0) # time of first sample
node1 = 'Axial_Base'
node2 = 'Eastern_Caldera'
filter_cutoffs = np.array([1, 95])
W = 90
htype = 'low_frequency'

NCF_object = NI.NCF(avg_time, start_time, node1, node2, filter_cutoffs, W, verbose=True, whiten=False)

# %%
num_periods = 2
NI.calculate_NCF_loop(num_periods, node1, node2, avg_time, start_time, W,  filter_cutoffs, verbose=True, htype=htype)
# Out:
# Calculting NCF for Period 0: 2017-03-10 00:00:00 -             2017-03-10 01:00:00
#    Getting Audio from Node 1...
#    Getting Audio from Node 2...
#    Filtering Data from node 1
#    Filtering Data from node 2
#    Correlating Data...
#    Time to Calculate NCF for 1 Average        Period: 4.355109214782715
#
#
# Calculting NCF for Period 1: 2017-03-10 01:00:00 -             2017-03-10 02:00:00
#    Getting Audio from Node 1...
#    Getting Audio from Node 2...
#    Filtering Data from node 1
#    Filtering Data from node 2
#    Correlating Data...
#    Time to Calculate NCF for 1 Average        Period: 2.5135209560394287
